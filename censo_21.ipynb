# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import chardet
import sys, os
import missingno as msno

# %%
# %reload_ext watermark
# %watermark -a "Leonardo da Silva Neves"
# Out:
# Author: Leonardo da Silva Neves

# %%
# Carregando DataFrames das edições do censo da educação superior.
censo_21 = 'censo_2021.csv'
file_ies = 'censo_ies/MICRODADOS_CADASTRO_IES_2021.CSV'

# %%
pd.set_option('display.max_columns', 200)

# %%
pd.set_option('display.max_rows', 500)

# %%
pd.set_option('display.max_colwidth', 100)

# %%
# Abrindo o arquivo como tipo binário 'rb' - 'read binary'
with open(censo_21, 'rb') as f1:
    raw_data = f1.read(1000000)

# %%
# Descobrindo a codificação do dataset com o método .detect() da biblioteca chardet.
result_23 = chardet.detect(raw_data)
cod_23 = result_23['encoding']
conf_23 = result_23['confidence']
print(f'codificação detectada: {cod_23} (confiança: {conf_23:.2f}%)')
# Out:
# codificação detectada: ISO-8859-1 (confiança: 0.73%)

# %%
df_21 = pd.read_csv(censo_21, sep=';', encoding=cod_23, low_memory=False, decimal=',')
df_21.shape
# Out:
# (444786, 194)

# %%
cols = ['CO_IES', 'NO_REGIAO_IES', 'CO_REGIAO_IES', 'NO_UF_IES', 'SG_UF_IES', 'CO_UF_IES', 'NO_MUNICIPIO_IES', 'CO_MUNICIPIO_IES', 'IN_CAPITAL_IES']

# %%
ies_21 = pd.read_csv(file_ies, sep=';', encoding=cod_23, low_memory=False, decimal=';', usecols=cols)
ies_21.shape
# Out:
# (2574, 9)

# %%
(df_21.isna().mean()*100).round(2)
# Out:
# NU_ANO_CENSO                    0.00
# CO_IES                          0.00
# NO_CURSO                        0.00
# CO_CURSO                        0.00
# TP_GRAU_ACADEMICO               0.07
# IN_GRATUITO                     0.00
# TP_MODALIDADE_ENSINO            0.00
# TP_NIVEL_ACADEMICO              0.00
# NO_CINE_AREA_GERAL              0.00
# CO_CINE_AREA_GERAL              0.00
# CO_CINE_AREA_ESPECIFICA         0.00
# NO_CINE_AREA_ESPECIFICA         0.00
# CO_CINE_AREA_DETALHADA          0.00
# NO_CINE_AREA_DETALHADA          0.00
# NO_REGIAO                       1.79
# CO_REGIAO                       1.79
# NO_UF                           1.79
# SG_UF                           1.79
# CO_UF                           1.79
# NO_MUNICIPIO                    1.79
# CO_MUNICIPIO                    1.79
# IN_CAPITAL                      1.79
# TP_DIMENSAO                     0.00
# TP_ORGANIZACAO_ACADEMICA        0.00
# TP_REDE                         0.00
# TP_CATEGORIA_ADMINISTRATIVA     0.00
# QT_CURSO                        0.00
# QT_VG_TOTAL                     0.00
# QT_VG_TOTAL_DIURNO              0.00
# QT_VG_TOTAL_NOTURNO             0.00
# QT_VG_TOTAL_EAD                 0.00
# QT_VG_NOVA                      0.00
# QT_VG_PROC_SELETIVO             0.00
# QT_VG_REMANESC                  0.00
# QT_VG_PROG_ESPECIAL             0.00
# QT_INSCRITO_TOTAL               0.00
# QT_INSCRITO_TOTAL_DIURNO        0.00
# QT_INSCRITO_TOTAL_NOTURNO       0.00
# QT_INSCRITO_TOTAL_EAD           0.00
# QT_INSC_VG_NOVA                 0.00
# QT_INSC_PROC_SELETIVO           0.00
# QT_INSC_VG_REMANESC             0.00
# QT_INSC_VG_PROG_ESPECIAL        0.00
# QT_ING                          0.00
# QT_ING_FEM                      0.00
# QT_ING_MASC                     0.00
# QT_ING_DIURNO                   0.00
# QT_ING_NOTURNO                  0.00
# QT_ING_VG_NOVA                  0.00
# QT_ING_VESTIBULAR               0.00
# QT_ING_ENEM                     0.00
# QT_ING_AVALIACAO_SERIADA        0.00
# QT_ING_SELECAO_SIMPLIFICA       0.00
# QT_ING_EGR                      0.00
# QT_ING_OUTRO_TIPO_SELECAO       0.00
# QT_ING_PROC_SELETIVO            0.00
# QT_ING_VG_REMANESC              0.00
# QT_ING_VG_PROG_ESPECIAL         0.00
# QT_ING_OUTRA_FORMA              0.00
# QT_ING_0_17                     0.00
# QT_ING_18_24                    0.00
# QT_ING_25_29                    0.00
# QT_ING_30_34                    0.00
# QT_ING_35_39                    0.00
# QT_ING_40_49                    0.00
# QT_ING_50_59                    0.00
# QT_ING_60_MAIS                  0.00
# QT_ING_BRANCA                   0.00
# QT_ING_PRETA                    0.00
# QT_ING_PARDA                    0.00
# QT_ING_AMARELA                  0.00
# QT_ING_INDIGENA                 0.00
# QT_ING_CORND                    0.00
# QT_MAT                          0.00
# QT_MAT_FEM                      0.00
# QT_MAT_MASC                     0.00
# QT_MAT_DIURNO                   0.00
# QT_MAT_NOTURNO                  0.00
# QT_MAT_0_17                     0.00
# QT_MAT_18_24                    0.00
# QT_MAT_25_29                    0.00
# QT_MAT_30_34                    0.00
# QT_MAT_35_39                    0.00
# QT_MAT_40_49                    0.00
# QT_MAT_50_59                    0.00
# QT_MAT_60_MAIS                  0.00
# QT_MAT_BRANCA                   0.00
# QT_MAT_PRETA                    0.00
# QT_MAT_PARDA                    0.00
# QT_MAT_AMARELA                  0.00
# QT_MAT_INDIGENA                 0.00
# QT_MAT_CORND                    0.00
# QT_CONC                         0.00
# QT_CONC_FEM                     0.00
# QT_CONC_MASC                    0.00
# QT_CONC_DIURNO                  0.00
# QT_CONC_NOTURNO                 0.00
# QT_CONC_0_17                    0.00
# QT_CONC_18_24                   0.00
# QT_CONC_25_29                   0.00
# QT_CONC_30_34                   0.00
# QT_CONC_35_39                   0.00
# QT_CONC_40_49                   0.00
# QT_CONC_50_59                   0.00
# QT_CONC_60_MAIS                 0.00
# QT_CONC_BRANCA                  0.00
# QT_CONC_PRETA                   0.00
# QT_CONC_PRETA.1                 0.00
# QT_CONC_AMARELA                 0.00
# QT_CONC_INDIGENA                0.00
# QT_CONC_CORND                   0.00
# QT_ING_NACBRAS                  0.00
# QT_ING_NACESTRANG               0.00
# QT_MAT_NACBRAS                  0.00
# QT_MAT_NACESTRANG               0.00
# QT_CONC_NACBRAS                 0.00
# QT_CONC_NACESTRANG              0.00
# QT_ALUNO_DEFICIENTE             0.00
# QT_ING_DEFICIENTE               0.00
# QT_MAT_DEFICIENTE               0.00
# QT_CONC_DEFICIENTE              0.00
# QT_ING_FINANC                   0.00
# QT_ING_FINANC_REEMB             0.00
# QT_ING_FIES                     0.00
# QT_ING_RPFIES                   0.00
# QT_ING_FINANC_REEMB_OUTROS      0.00
# QT_ING_FINANC_NREEMB            0.00
# QT_ING_PROUNII                  0.00
# QT_ING_PROUNIP                  0.00
# QT_ING_NRPFIES                  0.00
# QT_ING_FINANC_NREEMB_OUTROS     0.00
# QT_MAT_FINANC                   0.00
# QT_MAT_FINANC_REEMB             0.00
# QT_MAT_FIES                     0.00
# QT_MAT_RPFIES                   0.00
# QT_MAT_FINANC_REEMB_OUTROS      0.00
# QT_MAT_FINANC_NREEMB            0.00
# QT_MAT_PROUNII                  0.00
# QT_MAT_PROUNIP                  0.00
# QT_MAT_NRPFIES                  0.00
# QT_MAT_FINANC_NREEMB_OUTROS     0.00
# QT_CONC_FINANC                  0.00
# QT_CONC_FINANC_REEMB            0.00
# QT_CONC_FIES                    0.00
# QT_CONC_RPFIES                  0.00
# QT_CONC_FINANC_REEMB_OUTROS     0.00
# QT_CONC_FINANC_NREEMB           0.00
# QT_CONC_PROUNII                 0.00
# QT_CONC_PROUNIP                 0.00
# QT_CONC_NRPFIES                 0.00
# QT_CONC_FINANC_NREEMB_OUTROS    0.00
# QT_ING_RESERVA_VAGA             0.00
# QT_ING_RVREDEPUBLICA            0.00
# QT_ING_RVPDEF                   0.00
# QT_ING_RVSOCIAL_RF              0.00
# QT_ING_RVOUTROS                 0.00
# QT_MAT_RESERVA_VAGA             0.00
# QT_MAT_RVREDEPUBLICA            0.00
# QT_MAT_RVPDEF                   0.00
# QT_MAT_RVSOCIAL_RF              0.00
# QT_MAT_RVSOCIAL_RF.1            0.00
# QT_CONC_RESERVA_VAGA            0.00
# QT_CONC_RVREDEPUBLICA           0.00
# QT_CONC_RVSOCIAL_RF             0.00
# QT_CONC_RVOUTROS                0.00
# QT_SIT_TRANCADA                 0.00
# QT_SIT_DESVINCULADO             0.00
# QT_SIT_TRANSFERIDO              0.00
# QT_SIT_FALECIDO                 0.00
# QT_ING_PROCESCPUBLICA           0.00
# QT_ING_PROCESCPRIVADA           0.00
# QT_ING_PROCNAOINFORMADA         0.00
# QT_MAT_PROCESCPUBLICA           0.00
# QT_MAT_PROCESCPRIVADA           0.00
# QT_MAT_PROCNAOINFORMADA         0.00
# QT_CONC_PROCESCPUBLICA          0.00
# QT_CONC_PROCESCPRIVADA          0.00
# QT_CONC_PROCNAOINFORMADA        0.00
# QT_PARFOR                       0.00
# QT_ING_PARFOR                   0.00
# QT_MAT_PARFOR                   0.00
# QT_CONC_PARFOR                  0.00
# QT_APOIO_SOCIAL                 0.00
# QT_ING_APOIO_SOCIAL             0.00
# QT_MAT_APOIO_SOCIAL             0.00
# QT_CONC_APOIO_SOCIAL            0.00
# QT_ATIV_EXTRACURRICULAR         0.00
# QT_ING_ATIV_EXTRACURRICULAR     0.00
# QT_MAT_ATIV_EXTRACURRICULAR     0.00
# QT_CONC_ATIV_EXTRACURRICULAR    0.00
# QT_MOB_ACADEMICA                0.00
# QT_ING_MOB_ACADEMICA            0.00
# QT_MAT_MOB_ACADEMICA            0.00
# QT_CONC_MOB_ACADEMICA           0.00
# dtype: float64

# %%
# Selecionando apenas colunas com valores numéricos
colunas_quantidade = [col for col in df_21.columns if col.startswith('QT_')]
len(colunas_quantidade)
# Out:
# 168

# %%
# Preechendo os valores nulos (NaN) para evitar erros nas operações matemáricas, usando 0 nas colunas de contagem
for col in colunas_quantidade:
    df_21[col] = df_21[col].fillna(0)

# Solução alternativa usando .loc
# df_11.loc[:,colunas_quantidade] = df_11[colunas_quantidade].fillna(0)

# %% [markdown]
# Preenchendo os valores ausentes da coluna **'TP_GRAU_ACADEMICO'**

# %%
# 1. vou criar uma série (mascara booleana) (True onde é nan)
mask_na = df_21['TP_GRAU_ACADEMICO'].isna()

# %%
# 2. Aplicar a mascara boleanda para selecionar apenas as linhas com valor True
g_acadna = df_21[mask_na]

# %% [markdown]
# Para começar a preencher os valores ausentes da coluna 'TP_GRAU_ACADEMICO', algumas decisões de análise precisarão ser tomadas.
#
# Para reduzir o número de valores ausentes na coluna 'TP_NIVEL_ACADEMICO'

# %%
# 3. Verificando os valores únicos da variável 'TP_NIVEL_ACADEMICO'
g_acadna['TP_NIVEL_ACADEMICO'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
# 4. Criando uma mascara booleanda apenas com os cursos Sequencial de formação especifica.
mask_cs = g_acadna['TP_NIVEL_ACADEMICO'] == 2 # Sequencial de formação específica

# %%
# 5. Aplicando a mascara booleana para para selecionar apenas as linha com valor True da variável 'TP_NIVEL_ACADEMICO'
c_fesp = g_acadna[mask_cs]

# %%
c_fesp.shape
# Out:
# (17, 194)

# %%
# 6. Verificando as incidências de valores da variável 'NO_CINE_AREA_GERAL'
c_fesp['NO_CINE_AREA_GERAL'].value_counts()
# Out:
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             7
# Artes e humanidades                                           3
# Saúde e bem-estar                                             3
# Serviços                                                      2
# Computação e Tecnologias da Informação e Comunicação (TIC)    1
# Engenharia, produção e construção                             1
# Name: count, dtype: int64

# %%
# 7. Criando uma cópia do DataFrame para realizar as imputações
df_2021 = df_21.copy()

# %%
# 7.1 Checando as dimensões do novo DF
df_2021.shape
# Out:
# (444786, 194)

# %%
# 7.2 Verificando os valores ausentes na variável alvo.
df_2021['TP_GRAU_ACADEMICO'].isna().sum()
# Out:
# 309

# %%
# 7.3 Criando uma validação condicional utilizando as duas mascaras criadas anteriormente e atribuindo um novo valor para a variável alvo.
condition = (mask_na & mask_cs)
df_2021.loc[condition, 'TP_GRAU_ACADEMICO'] = 5 #  Sequencial de formação específica

# %%
# 7.4 Conferindo a redução no número valores ausentes na variável alvo
df_2021['TP_GRAU_ACADEMICO'].isna().sum()
# Out:
# 292

# %%
# 8. Criando uma nova mascara de seleção dos valores ausentes remanecentes na variável 'TP_GRAU_ACADEMICO'
mask1_na = df_2021['TP_GRAU_ACADEMICO'].isna()

# %%
# 8.1 Criação de um novo df filtrado pela mascara criada anteriormente
g_acadna1 = df_2021[mask1_na]

# %%
# 8.2 Verificação da dimensão do df olhando apenas para a quantidade de linhas
g_acadna1.shape[0]
# Out:
# 292

# %%
# 8.3 Verificando algumas amostras de linhas do DataFrame para verificar a insidência de algum padrão
g_acadna1.sample(5)
# Out:
#         NU_ANO_CENSO  CO_IES                   NO_CURSO  CO_CURSO  \
# 327610          2021      56               Abi - Física   5001029
# 247443          2021     586   Abi - Comunicação Social   5000682
# 247444          2021     586            Abi - Filosofia   5000775
# 177285          2021     573  Abi - Ciências Biológicas   5000632
# 69643           2021     578    Abi - Letras Vernáculas   5001141
#
#         TP_GRAU_ACADEMICO  IN_GRATUITO  TP_MODALIDADE_ENSINO  \
# 327610                NaN            1                     1
# 247443                NaN            1                     1
# 247444                NaN            1                     1
# 177285                NaN            1                     1
# 69643                 NaN            1                     1
#
#         TP_NIVEL_ACADEMICO NO_CINE_AREA_GERAL  CO_CINE_AREA_GERAL  \
# 327610                   1  Programas básicos                   0
# 247443                   1  Programas básicos                   0
# 247444                   1  Programas básicos                   0
# 177285                   1  Programas básicos                   0
# 69643                    1  Programas básicos                   0
#
#         CO_CINE_AREA_ESPECIFICA NO_CINE_AREA_ESPECIFICA  \
# 327610                        1       Programas básicos
# 247443                        1       Programas básicos
# 247444                        1       Programas básicos
# 177285                        1       Programas básicos
# 69643                         1       Programas básicos
#
#         CO_CINE_AREA_DETALHADA NO_CINE_AREA_DETALHADA NO_REGIAO  CO_REGIAO  \
# 327610                      11      Programas básicos   Sudeste        3.0
# 247443                      11      Programas básicos   Sudeste        3.0
# 247444                      11      Programas básicos   Sudeste        3.0
# 177285                      11      Programas básicos   Sudeste        3.0
# 69643                       11      Programas básicos  Nordeste        2.0
#
#                  NO_UF SG_UF  CO_UF           NO_MUNICIPIO  CO_MUNICIPIO  \
# 327610       São Paulo    SP   35.0  São José do Rio Preto     3549805.0
# 247443  Rio de Janeiro    RJ   33.0         Rio de Janeiro     3304557.0
# 247444  Rio de Janeiro    RJ   33.0         Rio de Janeiro     3304557.0
# 177285  Espírito Santo    ES   32.0                Vitória     3205309.0
# 69643            Bahia    BA   29.0               Salvador     2927408.0
#
#         IN_CAPITAL  TP_DIMENSAO  TP_ORGANIZACAO_ACADEMICA  TP_REDE  \
# 327610         0.0            1                         1        1
# 247443         1.0            1                         1        1
# 247444         1.0            1                         1        1
# 177285         1.0            1                         1        1
# 69643          1.0            1                         1        1
#
#         TP_CATEGORIA_ADMINISTRATIVA  QT_CURSO  QT_VG_TOTAL  \
# 327610                            2         0           79
# 247443                            1         0          178
# 247444                            1         0           91
# 177285                            1         0           70
# 69643                             1         0          123
#
#         QT_VG_TOTAL_DIURNO  QT_VG_TOTAL_NOTURNO  QT_VG_TOTAL_EAD  QT_VG_NOVA  \
# 327610                  79                    0                0          55
# 247443                  84                   94                0         160
# 247444                  91                    0                0          80
# 177285                  70                    0                0          70
# 69643                  123                    0                0          90
#
#         QT_VG_PROC_SELETIVO  QT_VG_REMANESC  QT_VG_PROG_ESPECIAL  \
# 327610                    0              24                    0
# 247443                    0              18                    0
# 247444                    0              11                    0
# 177285                    0               0                    0
# 69643                     0              33                    0
#
#         QT_INSCRITO_TOTAL  QT_INSCRITO_TOTAL_DIURNO  \
# 327610                 96                        96
# 247443               3313                      1799
# 247444                591                       591
# 177285                761                       761
# 69643                 540                       540
#
#         QT_INSCRITO_TOTAL_NOTURNO  QT_INSCRITO_TOTAL_EAD  QT_INSC_VG_NOVA  \
# 327610                          0                      0               91
# 247443                       1514                      0             3282
# 247444                          0                      0              586
# 177285                          0                      0              761
# 69643                           0                      0              487
#
#         QT_INSC_PROC_SELETIVO  QT_INSC_VG_REMANESC  QT_INSC_VG_PROG_ESPECIAL  \
# 327610                      0                    5                         0
# 247443                      0                   31                         0
# 247444                      0                    5                         0
# 177285                      0                    0                         0
# 69643                       0                   53                         0
#
#         QT_ING  QT_ING_FEM  QT_ING_MASC  QT_ING_DIURNO  QT_ING_NOTURNO  \
# 327610      50          20           30             50               0
# 247443     167         109           58             81              86
# 247444      83          45           38             83               0
# 177285      70          43           27             70               0
# 69643       98          70           28             98               0
#
#         QT_ING_VG_NOVA  QT_ING_VESTIBULAR  QT_ING_ENEM  \
# 327610              49                 49            0
# 247443             160                  0          160
# 247444              79                  0           79
# 177285              70                  0           70
# 69643               65                  0           65
#
#         QT_ING_AVALIACAO_SERIADA  QT_ING_SELECAO_SIMPLIFICA  QT_ING_EGR  \
# 327610                         0                          0           0
# 247443                         0                          0           0
# 247444                         0                          0           0
# 177285                         0                          0           0
# 69643                          0                          0           0
#
#         QT_ING_OUTRO_TIPO_SELECAO  QT_ING_PROC_SELETIVO  QT_ING_VG_REMANESC  \
# 327610                          0                     0                   1
# 247443                          0                     0                   7
# 247444                          0                     0                   4
# 177285                          0                     0                   0
# 69643                           0                     0                  33
#
#         QT_ING_VG_PROG_ESPECIAL  QT_ING_OUTRA_FORMA  QT_ING_0_17  \
# 327610                        0                   0            0
# 247443                        0                   0            0
# 247444                        0                   0            1
# 177285                        0                   0            0
# 69643                         0                   0            0
#
#         QT_ING_18_24  QT_ING_25_29  QT_ING_30_34  QT_ING_35_39  QT_ING_40_49  \
# 327610            46             1             1             0             1
# 247443           154            12             0             1             0
# 247444            57            12             4             3             2
# 177285            63             4             2             1             0
# 69643             69            16             4             4             4
#
#         QT_ING_50_59  QT_ING_60_MAIS  QT_ING_BRANCA  QT_ING_PRETA  \
# 327610             1               0             41             2
# 247443             0               0             74            27
# 247444             3               1             39            11
# 177285             0               0             37            11
# 69643              1               0             14            17
#
#         QT_ING_PARDA  QT_ING_AMARELA  QT_ING_INDIGENA  QT_ING_CORND  QT_MAT  \
# 327610             7               0                0             0      40
# 247443            42               0                1            23     239
# 247444            22               0                0            11     116
# 177285            20               1                0             1     255
# 69643             37               0                0            30     303
#
#         QT_MAT_FEM  QT_MAT_MASC  QT_MAT_DIURNO  QT_MAT_NOTURNO  QT_MAT_0_17  \
# 327610          15           25             40               0            0
# 247443         151           88            107             132            0
# 247444          62           54            116               0            1
# 177285         162           93            255               0            0
# 69643          220           83            303               0            0
#
#         QT_MAT_18_24  QT_MAT_25_29  QT_MAT_30_34  QT_MAT_35_39  QT_MAT_40_49  \
# 327610            36             1             1             0             1
# 247443           221            13             2             3             0
# 247444            72            19            10             3             3
# 177285           224            24             6             1             0
# 69643            174            58            25            16            15
#
#         QT_MAT_50_59  QT_MAT_60_MAIS  QT_MAT_BRANCA  QT_MAT_PRETA  \
# 327610             1               0             33             2
# 247443             0               0            104            43
# 247444             3               5             52            18
# 177285             0               0            118            32
# 69643             11               4             34            67
#
#         QT_MAT_PARDA  QT_MAT_AMARELA  QT_MAT_INDIGENA  QT_MAT_CORND  QT_CONC  \
# 327610             5               0                0             0        0
# 247443            65               0                1            26        0
# 247444            31               0                0            15        0
# 177285            89               4                0            12        0
# 69643            126               1                0            75        0
#
#         QT_CONC_FEM  QT_CONC_MASC  QT_CONC_DIURNO  QT_CONC_NOTURNO  \
# 327610            0             0               0                0
# 247443            0             0               0                0
# 247444            0             0               0                0
# 177285            0             0               0                0
# 69643             0             0               0                0
#
#         QT_CONC_0_17  QT_CONC_18_24  QT_CONC_25_29  QT_CONC_30_34  \
# 327610             0              0              0              0
# 247443             0              0              0              0
# 247444             0              0              0              0
# 177285             0              0              0              0
# 69643              0              0              0              0
#
#         QT_CONC_35_39  QT_CONC_40_49  QT_CONC_50_59  QT_CONC_60_MAIS  \
# 327610              0              0              0                0
# 247443              0              0              0                0
# 247444              0              0              0                0
# 177285              0              0              0                0
# 69643               0              0              0                0
#
#         QT_CONC_BRANCA  QT_CONC_PRETA  QT_CONC_PRETA.1  QT_CONC_AMARELA  \
# 327610               0              0                0                0
# 247443               0              0                0                0
# 247444               0              0                0                0
# 177285               0              0                0                0
# 69643                0              0                0                0
#
#         QT_CONC_INDIGENA  QT_CONC_CORND  QT_ING_NACBRAS  QT_ING_NACESTRANG  \
# 327610                 0              0              50                  0
# 247443                 0              0             167                  0
# 247444                 0              0              83                  0
# 177285                 0              0              70                  0
# 69643                  0              0              98                  0
#
#         QT_MAT_NACBRAS  QT_MAT_NACESTRANG  QT_CONC_NACBRAS  \
# 327610              40                  0                0
# 247443             239                  0                0
# 247444             116                  0                0
# 177285             253                  2                0
# 69643              302                  1                0
#
#         QT_CONC_NACESTRANG  QT_ALUNO_DEFICIENTE  QT_ING_DEFICIENTE  \
# 327610                   0                    0                  0
# 247443                   0                    7                  0
# 247444                   0                    6                  1
# 177285                   0                    3                  0
# 69643                    0                    5                  0
#
#         QT_MAT_DEFICIENTE  QT_CONC_DEFICIENTE  QT_ING_FINANC  \
# 327610                  0                   0              0
# 247443                  2                   0              0
# 247444                  1                   0              0
# 177285                  3                   0              0
# 69643                   3                   0              0
#
#         QT_ING_FINANC_REEMB  QT_ING_FIES  QT_ING_RPFIES  \
# 327610                    0            0              0
# 247443                    0            0              0
# 247444                    0            0              0
# 177285                    0            0              0
# 69643                     0            0              0
#
#         QT_ING_FINANC_REEMB_OUTROS  QT_ING_FINANC_NREEMB  QT_ING_PROUNII  \
# 327610                           0                     0               0
# 247443                           0                     0               0
# 247444                           0                     0               0
# 177285                           0                     0               0
# 69643                            0                     0               0
#
#         QT_ING_PROUNIP  QT_ING_NRPFIES  QT_ING_FINANC_NREEMB_OUTROS  \
# 327610               0               0                            0
# 247443               0               0                            0
# 247444               0               0                            0
# 177285               0               0                            0
# 69643                0               0                            0
#
#         QT_MAT_FINANC  QT_MAT_FINANC_REEMB  QT_MAT_FIES  QT_MAT_RPFIES  \
# 327610              0                    0            0              0
# 247443              0                    0            0              0
# 247444              0                    0            0              0
# 177285              0                    0            0              0
# 69643               0                    0            0              0
#
#         QT_MAT_FINANC_REEMB_OUTROS  QT_MAT_FINANC_NREEMB  QT_MAT_PROUNII  \
# 327610                           0                     0               0
# 247443                           0                     0               0
# 247444                           0                     0               0
# 177285                           0                     0               0
# 69643                            0                     0               0
#
#         QT_MAT_PROUNIP  QT_MAT_NRPFIES  QT_MAT_FINANC_NREEMB_OUTROS  \
# 327610               0               0                            0
# 247443               0               0                            0
# 247444               0               0                            0
# 177285               0               0                            0
# 69643                0               0                            0
#
#         QT_CONC_FINANC  QT_CONC_FINANC_REEMB  QT_CONC_FIES  QT_CONC_RPFIES  \
# 327610               0                     0             0               0
# 247443               0                     0             0               0
# 247444               0                     0             0               0
# 177285               0                     0             0               0
# 69643                0                     0             0               0
#
#         QT_CONC_FINANC_REEMB_OUTROS  QT_CONC_FINANC_NREEMB  QT_CONC_PROUNII  \
# 327610                            0                      0                0
# 247443                            0                      0                0
# 247444                            0                      0                0
# 177285                            0                      0                0
# 69643                             0                      0                0
#
#         QT_CONC_PROUNIP  QT_CONC_NRPFIES  QT_CONC_FINANC_NREEMB_OUTROS  \
# 327610                0                0                             0
# 247443                0                0                             0
# 247444                0                0                             0
# 177285                0                0                             0
# 69643                 0                0                             0
#
#         QT_ING_RESERVA_VAGA  QT_ING_RVREDEPUBLICA  QT_ING_RVPDEF  \
# 327610                   24                    20              0
# 247443                   80                    80              0
# 247444                   40                    40              0
# 177285                   34                     7              0
# 69643                    32                    32              0
#
#         QT_ING_RVSOCIAL_RF  QT_ING_RVOUTROS  QT_MAT_RESERVA_VAGA  \
# 327610                   0                0                   19
# 247443                  40                0                  130
# 247444                  21                0                   55
# 177285                   5               11                  126
# 69643                   14                0                  121
#
#         QT_MAT_RVREDEPUBLICA  QT_MAT_RVPDEF  QT_MAT_RVSOCIAL_RF  \
# 327610                    17              0                   0
# 247443                   130              0                  69
# 247444                    55              0                  23
# 177285                    20              0                  20
# 69643                    121              1                  55
#
#         QT_MAT_RVSOCIAL_RF.1  QT_CONC_RESERVA_VAGA  QT_CONC_RVREDEPUBLICA  \
# 327610                     0                     0                      0
# 247443                    69                     0                      0
# 247444                    23                     0                      0
# 177285                    20                     0                      0
# 69643                     55                     0                      0
#
#         QT_CONC_RVSOCIAL_RF  QT_CONC_RVOUTROS  QT_SIT_TRANCADA  \
# 327610                    0                 0                2
# 247443                    0                 0               82
# 247444                    0                 0              106
# 177285                    0                 0               10
# 69643                     0                 0              215
#
#         QT_SIT_DESVINCULADO  QT_SIT_TRANSFERIDO  QT_SIT_FALECIDO  \
# 327610                   25                  22                0
# 247443                   24                 121                0
# 247444                   16                  42                0
# 177285                   29                  82                0
# 69643                    19                  39                0
#
#         QT_ING_PROCESCPUBLICA  QT_ING_PROCESCPRIVADA  QT_ING_PROCNAOINFORMADA  \
# 327610                     27                     23                        0
# 247443                     86                     81                        0
# 247444                     54                     29                        0
# 177285                     60                     10                        0
# 69643                      40                     58                        0
#
#         QT_MAT_PROCESCPUBLICA  QT_MAT_PROCESCPRIVADA  QT_MAT_PROCNAOINFORMADA  \
# 327610                     22                     18                        0
# 247443                    134                    105                        0
# 247444                     73                     43                        0
# 177285                    209                     46                        0
# 69643                     144                    159                        0
#
#         QT_CONC_PROCESCPUBLICA  QT_CONC_PROCESCPRIVADA  \
# 327610                       0                       0
# 247443                       0                       0
# 247444                       0                       0
# 177285                       0                       0
# 69643                        0                       0
#
#         QT_CONC_PROCNAOINFORMADA  QT_PARFOR  QT_ING_PARFOR  QT_MAT_PARFOR  \
# 327610                         0          0              0              0
# 247443                         0          0              0              0
# 247444                         0          0              0              0
# 177285                         0          0              0              0
# 69643                          0          0              0              0
#
#         QT_CONC_PARFOR  QT_APOIO_SOCIAL  QT_ING_APOIO_SOCIAL  \
# 327610               0               11                    6
# 247443               0              466                  167
# 247444               0              280                   83
# 177285               0                0                    0
# 69643                0               44                    5
#
#         QT_MAT_APOIO_SOCIAL  QT_CONC_APOIO_SOCIAL  QT_ATIV_EXTRACURRICULAR  \
# 327610                    7                     0                        5
# 247443                  239                     0                      119
# 247444                  116                     0                       18
# 177285                    0                     0                        0
# 69643                    39                     0                      100
#
#         QT_ING_ATIV_EXTRACURRICULAR  QT_MAT_ATIV_EXTRACURRICULAR  \
# 327610                            2                            2
# 247443                           21                           49
# 247444                            0                            6
# 177285                            0                            0
# 69643                             3                           86
#
#         QT_CONC_ATIV_EXTRACURRICULAR  QT_MOB_ACADEMICA  QT_ING_MOB_ACADEMICA  \
# 327610                             0                 1                     0
# 247443                             0                 0                     0
# 247444                             0                 0                     0
# 177285                             0                 0                     0
# 69643                              0                 0                     0
#
#         QT_MAT_MOB_ACADEMICA  QT_CONC_MOB_ACADEMICA
# 327610                     0                      0
# 247443                     0                      0
# 247444                     0                      0
# 177285                     0                      0
# 69643                      0                      0

# %%
# 8.4 Analisando algumas estatísticas das variáveis não númericas do DataFrame
g_acadna1.describe(include = 'object')
# Out:
#                      NO_CURSO NO_CINE_AREA_GERAL NO_CINE_AREA_ESPECIFICA  \
# count                     292                292                     292
# unique                     69                  1                       1
# top     Abi - Educação Física  Programas básicos       Programas básicos
# freq                       65                292                     292
#
#        NO_CINE_AREA_DETALHADA NO_REGIAO      NO_UF SG_UF    NO_MUNICIPIO
# count                     292       288        288   288             288
# unique                      1         5         19    19              93
# top         Programas básicos   Sudeste  São Paulo    SP  Rio de Janeiro
# freq                      292       167         84    84              19

# %%
#  8.4.1 Verificando as regiões do Brasil que não preencheram a variável ´TP_GRAU_ACADEMICO´ para o cursos diferentes de ...
# 'Sequencial de formação especifica"
g_acadna1['NO_REGIAO'].value_counts()
# Out:
# NO_REGIAO
# Sudeste         167
# Sul              56
# Centro-Oeste     29
# Nordeste         27
# Norte             9
# Name: count, dtype: int64

# %%
# 8.4.2 Verificando insidência de valores ausentes por tipo de Rede (Pública e Privada)
g_acadna1['TP_REDE'].value_counts()
# Out:
# TP_REDE
# 1    230
# 2     62
# Name: count, dtype: int64

# %%
# 8.4.3 Visualizando a ocorrência dos cursos para determinar quais são bacharelados por definição e quais não são.
g_acadna1['NO_CURSO'].value_counts()
# Out:
# NO_CURSO
# Abi - Educação Física                                                                       65
# Abi - Ciências Biológicas                                                                   24
# Abi - Ciências Sociais                                                                      18
# Abi - Geografia                                                                             16
# Abi - Matemática                                                                            13
# Abi - História                                                                              13
# Abi - Física                                                                                13
# Abi - Química                                                                               13
# Abi - Filosofia                                                                             12
# Abi - Letras                                                                                11
# Abi - Engenharia                                                                             7
# Abi - Música                                                                                 5
# Abi - Artes Visuais                                                                          5
# Abi - Ciências Exatas                                                                        4
# Abi - Psicologia                                                                             3
# Abi - Teatro                                                                                 3
# Abi - Licenciaturas Interdisciplinares                                                       3
# Abi - Artes Cênicas                                                                          3
# Matemática - Licenciatura Ou Bacharelado                                                     2
# Abi - Letras - Português - Frances                                                           2
# Abi - Enfermagem                                                                             2
# Abi - Letras Inglês                                                                          2
# Abi - Educação Física E Esporte                                                              2
# Abi - Letras - Português - Ingles                                                            2
# Abi - Letras - Português - Espanhol                                                          2
# Abi - Dança                                                                                  2
# Abi - Design                                                                                 2
# Abi - Letras Francês                                                                         2
# Ciências Biológicas - Licenciatura Ou Bacharelado                                            1
# Geografia - Licenciatura Ou Bacharelado                                                      1
# Abi - Física, Matemática/Matemática Aplicada E Computacional                                 1
# História - Licenciatura Ou Bacharelado                                                       1
# Abi - Letras Português                                                                       1
# Ciências Sociais - Licenciatura Ou Bacharelado                                               1
# Química - Licenciatura Ou Bacharelado                                                        1
# Abi - Engenharia Elétrica                                                                    1
# Abi - Ciências Biomédicas                                                                    1
# Finanças E Negócios                                                                          1
# Abi - Ciclo Básico Composição/Regência                                                       1
# Abi - Ciclo Básico Materiais/Metalúrgica/Nuclear                                             1
# Abi - Letras Português - Alemão                                                              1
# Abi - Matemática Aplicada                                                                    1
# Abi - Matemática Aplicada E Computacional                                                    1
# Abi - Letras Alemão                                                                          1
# Abi - Letras Espanhol                                                                        1
# Abi - Letras Italiano                                                                        1
# Abi - Literaturas De Língua Portuguesa                                                       1
# Abi - Ciências Da Natureza: Ciências E Biologia, Ciências E Física Ou Ciências E Química     1
# Abi - Letras - Português - Russo                                                             1
# Abi - Língua Estrangeira                                                                     1
# Abi - Letras - Língua Portuguesa                                                             1
# Abi - Ciência Da Computação                                                                  1
# Abi - Educação Intercultural                                                                 1
# Computação                                                                                   1
# Abi - Composição E Regência                                                                  1
# Abi - Engenharia De Minas                                                                    1
# Abi - Letras Vernáculas                                                                      1
# Abi - Letras Vernáculas E Língua Estrangeira Moderna                                         1
# Abi - Língua Estrangeira Moderna Ou Clássica                                                 1
# Abi - Letras - Português - Latim                                                             1
# Abi - Música Popular                                                                         1
# Abi - Licenciatura Intercultural                                                             1
# Abi - Comunicação Social                                                                     1
# Abi - Letras - Português - Arabe                                                             1
# Abi - Letras - Português - Grego                                                             1
# Abi - Letras - Português - Hebraico                                                          1
# Abi - Letras - Português - Italiano                                                          1
# Abi - Letras - Português - Japones                                                           1
# Abi - Letras Língua Portuguesa                                                               1
# Name: count, dtype: int64

# %%
g_acadna1['NO_CURSO'].unique()
# Out:
# array(['Abi - Educação Física', 'Abi - Ciências Sociais', 'Abi - Design',
#        'Abi - Engenharia', 'Abi - Filosofia', 'Abi - Geografia',
#        'Abi - História', 'Abi - Letras - Língua Portuguesa',
#        'Abi - Letras Francês', 'Abi - Letras Inglês', 'Abi - Matemática',
#        'Abi - Música', 'Abi - Psicologia', 'Abi - Ciência Da Computação',
#        'Abi - Química', 'Abi - Educação Intercultural',
#        'Abi - Artes Cênicas', 'Abi - Letras', 'Computação',
#        'Abi - Licenciaturas Interdisciplinares',
#        'Abi - Ciências Biológicas', 'Abi - Composição E Regência',
#        'Abi - Dança', 'Abi - Engenharia De Minas', 'Abi - Física',
#        'Abi - Letras Vernáculas',
#        'Abi - Letras Vernáculas E Língua Estrangeira Moderna',
#        'Abi - Língua Estrangeira',
#        'Abi - Língua Estrangeira Moderna Ou Clássica',
#        'Abi - Música Popular', 'Abi - Teatro',
#        'Abi - Licenciatura Intercultural', 'Abi - Artes Visuais',
#        'Abi - Enfermagem',
#        'Abi - Ciências Da Natureza: Ciências E Biologia, Ciências E Física Ou Ciências E Química',
#        'Matemática - Licenciatura Ou Bacharelado',
#        'Abi - Comunicação Social', 'Abi - Letras - Português - Arabe',
#        'Abi - Letras - Português - Espanhol',
#        'Abi - Letras - Português - Frances',
#        'Abi - Letras - Português - Grego',
#        'Abi - Letras - Português - Hebraico',
#        'Abi - Letras - Português - Ingles',
#        'Abi - Letras - Português - Italiano',
#        'Abi - Letras - Português - Japones',
#        'Abi - Letras - Português - Latim',
#        'Abi - Letras - Português - Russo',
#        'Abi - Letras Português - Alemão',
#        'Abi - Literaturas De Língua Portuguesa',
#        'Ciências Biológicas - Licenciatura Ou Bacharelado',
#        'Ciências Sociais - Licenciatura Ou Bacharelado',
#        'Geografia - Licenciatura Ou Bacharelado',
#        'História - Licenciatura Ou Bacharelado',
#        'Química - Licenciatura Ou Bacharelado',
#        'Abi - Física, Matemática/Matemática Aplicada E Computacional',
#        'Abi - Letras Português', 'Abi - Ciências Biomédicas',
#        'Abi - Educação Física E Esporte', 'Finanças E Negócios',
#        'Abi - Ciências Exatas', 'Abi - Ciclo Básico Composição/Regência',
#        'Abi - Ciclo Básico Materiais/Metalúrgica/Nuclear',
#        'Abi - Engenharia Elétrica', 'Abi - Matemática Aplicada',
#        'Abi - Matemática Aplicada E Computacional', 'Abi - Letras Alemão',
#        'Abi - Letras Espanhol', 'Abi - Letras Italiano',
#        'Abi - Letras Língua Portuguesa'], dtype=object)

# %%
# 8.4.4 Criando uma mascara classificando os cursos de licenciatura e bacharelado
bacharelado = [
    'Abi - Design',
    'Abi - Engenharia',
    'Abi - Psicologia',
    'Abi - Ciência Da Computação',
    'Abi - Engenharia De Minas',
    'Abi - Enfermagem',
    'Abi - Comunicação Social',
    'Abi - Ciências Biomédicas',
    'Finanças E Negócios',
    'Abi - Ciclo Básico Materiais/Metalúrgica/Nuclear',
    'Abi - Engenharia Elétrica',
    'Computação'
]
len(bacharelado)
# Out:
# 12

# %%
# 8.4.4.2 Criando a condição lógica para definir a atribuição de valores para as outras variáveis
lic_bac = cursos_licenciatura_ou_bacharelado = [
    'Abi - Educação Física',
    'Abi - Ciências Sociais',
    'Abi - Filosofia',
    'Abi - Geografia',
    'Abi - História',
    'Abi - Matemática',
    'Abi - Química',
    'Abi - Educação Intercultural',
    'Abi - Artes Cênicas',
    'Abi - Letras',
    'Abi - Licenciaturas Interdisciplinares',
    'Abi - Ciências Biológicas',
    'Abi - Composição E Regência',
    'Abi - Dança',
    'Abi - Física',
    'Abi - Letras Vernáculas',
    'Abi - Letras Vernáculas E Língua Estrangeira Moderna',
    'Abi - Língua Estrangeira',
    'Abi - Língua Estrangeira Moderna Ou Clássica',
    'Abi - Música Popular',
    'Abi - Teatro',
    'Abi - Licenciatura Intercultural',
    'Abi - Artes Visuais',
    'Abi - Ciências Da Natureza: Ciências E Biologia, Ciências E Física Ou Ciências E Química',
    'Abi - Letras - Língua Portuguesa',
    'Abi - Letras Francês',
    'Abi - Letras Inglês',
    'Abi - Música',
    'Abi - Letras Alemão',
    'Abi - Letras Espanhol',
    'Abi - Letras Italiano',
    'Abi - Letras Língua Portuguesa',
    'Abi - Letras - Português - Arabe',
    'Abi - Letras - Português - Espanhol',
    'Abi - Letras - Português - Frances',
    'Abi - Letras - Português - Grego',
    'Abi - Letras - Português - Hebraico',
    'Abi - Letras - Português - Ingles',
    'Abi - Letras - Português - Italiano',
    'Abi - Letras - Português - Japones',
    'Abi - Letras - Português - Latim',
    'Abi - Letras - Português - Russo',
    'Abi - Letras Português - Alemão',
    'Abi - Literaturas De Língua Portuguesa',
    'Abi - Física, Matemática/Matemática Aplicada E Computacional',
    'Abi - Letras Português',
    'Abi - Educação Física E Esporte',
    'Abi - Ciências Exatas',
    'Abi - Ciclo Básico Composição/Regência',
    'Abi - Matemática Aplicada',
    'Abi - Matemática Aplicada E Computacional',
    'Matemática - Licenciatura Ou Bacharelado',
    'Ciências Biológicas - Licenciatura Ou Bacharelado',
    'Ciências Sociais - Licenciatura Ou Bacharelado',
    'Geografia - Licenciatura Ou Bacharelado',
    'História - Licenciatura Ou Bacharelado',
    'Química - Licenciatura Ou Bacharelado'
]

# %%
# 8.4.4.1 Criando a condição lógica para definir a atribuição de valores
mask2 = df_2021['NO_CURSO'].isin(bacharelado)
mask3 = df_2021['TP_GRAU_ACADEMICO'].isna()
mask4 = df_2021['NO_CURSO'].isin(lic_bac)
condiction1 = (mask2 & mask3)
condiction2 = (mask4 & mask3)

# %%
# Conferindo número de atribuições da condiction1
condiction1.sum()
# Out:
# 22

# %%
df_2021['TP_GRAU_ACADEMICO'].isna().sum()
# Out:
# 292

# %%
# 8.4.4.3 Atribuição para os registros que atendem a condição de não licenciaturas
df_2021.loc[condiction1, 'TP_GRAU_ACADEMICO'] = 1 # Bacharelado

# %%
df_2021['TP_GRAU_ACADEMICO'].isna().sum()
# Out:
# 270

# %%
# 8.4.4.4 Atribuição para os registros que atendem a condição de licenciaturas
df_2021.loc[condiction2, 'TP_GRAU_ACADEMICO'] = 4 # Bacharelado ou licenciaturas

# %%
# Verificando o número de atribuições da condiction2
condiction2.sum()
# Out:
# 270

# %%
# 9. Verificação da incidência de valores nulos na variável 'TP_GRAU_ACADEMICO'
df_2021['TP_GRAU_ACADEMICO'].isna().sum()
# Out:
# 0

# %%
df_tgau = df_2021['TP_GRAU_ACADEMICO'].isna()

# %%
df = df_2020[df_tgau]

# %%
df['NO_CURSO'].unique()

# %% [markdown]
# **Tratamento das demais variáveis com valores ausentes**
#
# ['NO_REGIAO', 'CO_REGIAO', 'NO_UF', 'SG_UF', 'CO_UF', 'NO_MUNICIPIO', 'CO_MUNICIPIO', 'IN_CAPITAL']

# %%
(df_2021.isna().mean()*100).round(2)
# Out:
# NU_ANO_CENSO                    0.00
# CO_IES                          0.00
# NO_CURSO                        0.00
# CO_CURSO                        0.00
# TP_GRAU_ACADEMICO               0.00
# IN_GRATUITO                     0.00
# TP_MODALIDADE_ENSINO            0.00
# TP_NIVEL_ACADEMICO              0.00
# NO_CINE_AREA_GERAL              0.00
# CO_CINE_AREA_GERAL              0.00
# CO_CINE_AREA_ESPECIFICA         0.00
# NO_CINE_AREA_ESPECIFICA         0.00
# CO_CINE_AREA_DETALHADA          0.00
# NO_CINE_AREA_DETALHADA          0.00
# NO_REGIAO                       1.79
# CO_REGIAO                       1.79
# NO_UF                           1.79
# SG_UF                           1.79
# CO_UF                           1.79
# NO_MUNICIPIO                    1.79
# CO_MUNICIPIO                    1.79
# IN_CAPITAL                      1.79
# TP_DIMENSAO                     0.00
# TP_ORGANIZACAO_ACADEMICA        0.00
# TP_REDE                         0.00
# TP_CATEGORIA_ADMINISTRATIVA     0.00
# QT_CURSO                        0.00
# QT_VG_TOTAL                     0.00
# QT_VG_TOTAL_DIURNO              0.00
# QT_VG_TOTAL_NOTURNO             0.00
# QT_VG_TOTAL_EAD                 0.00
# QT_VG_NOVA                      0.00
# QT_VG_PROC_SELETIVO             0.00
# QT_VG_REMANESC                  0.00
# QT_VG_PROG_ESPECIAL             0.00
# QT_INSCRITO_TOTAL               0.00
# QT_INSCRITO_TOTAL_DIURNO        0.00
# QT_INSCRITO_TOTAL_NOTURNO       0.00
# QT_INSCRITO_TOTAL_EAD           0.00
# QT_INSC_VG_NOVA                 0.00
# QT_INSC_PROC_SELETIVO           0.00
# QT_INSC_VG_REMANESC             0.00
# QT_INSC_VG_PROG_ESPECIAL        0.00
# QT_ING                          0.00
# QT_ING_FEM                      0.00
# QT_ING_MASC                     0.00
# QT_ING_DIURNO                   0.00
# QT_ING_NOTURNO                  0.00
# QT_ING_VG_NOVA                  0.00
# QT_ING_VESTIBULAR               0.00
# QT_ING_ENEM                     0.00
# QT_ING_AVALIACAO_SERIADA        0.00
# QT_ING_SELECAO_SIMPLIFICA       0.00
# QT_ING_EGR                      0.00
# QT_ING_OUTRO_TIPO_SELECAO       0.00
# QT_ING_PROC_SELETIVO            0.00
# QT_ING_VG_REMANESC              0.00
# QT_ING_VG_PROG_ESPECIAL         0.00
# QT_ING_OUTRA_FORMA              0.00
# QT_ING_0_17                     0.00
# QT_ING_18_24                    0.00
# QT_ING_25_29                    0.00
# QT_ING_30_34                    0.00
# QT_ING_35_39                    0.00
# QT_ING_40_49                    0.00
# QT_ING_50_59                    0.00
# QT_ING_60_MAIS                  0.00
# QT_ING_BRANCA                   0.00
# QT_ING_PRETA                    0.00
# QT_ING_PARDA                    0.00
# QT_ING_AMARELA                  0.00
# QT_ING_INDIGENA                 0.00
# QT_ING_CORND                    0.00
# QT_MAT                          0.00
# QT_MAT_FEM                      0.00
# QT_MAT_MASC                     0.00
# QT_MAT_DIURNO                   0.00
# QT_MAT_NOTURNO                  0.00
# QT_MAT_0_17                     0.00
# QT_MAT_18_24                    0.00
# QT_MAT_25_29                    0.00
# QT_MAT_30_34                    0.00
# QT_MAT_35_39                    0.00
# QT_MAT_40_49                    0.00
# QT_MAT_50_59                    0.00
# QT_MAT_60_MAIS                  0.00
# QT_MAT_BRANCA                   0.00
# QT_MAT_PRETA                    0.00
# QT_MAT_PARDA                    0.00
# QT_MAT_AMARELA                  0.00
# QT_MAT_INDIGENA                 0.00
# QT_MAT_CORND                    0.00
# QT_CONC                         0.00
# QT_CONC_FEM                     0.00
# QT_CONC_MASC                    0.00
# QT_CONC_DIURNO                  0.00
# QT_CONC_NOTURNO                 0.00
# QT_CONC_0_17                    0.00
# QT_CONC_18_24                   0.00
# QT_CONC_25_29                   0.00
# QT_CONC_30_34                   0.00
# QT_CONC_35_39                   0.00
# QT_CONC_40_49                   0.00
# QT_CONC_50_59                   0.00
# QT_CONC_60_MAIS                 0.00
# QT_CONC_BRANCA                  0.00
# QT_CONC_PRETA                   0.00
# QT_CONC_PRETA.1                 0.00
# QT_CONC_AMARELA                 0.00
# QT_CONC_INDIGENA                0.00
# QT_CONC_CORND                   0.00
# QT_ING_NACBRAS                  0.00
# QT_ING_NACESTRANG               0.00
# QT_MAT_NACBRAS                  0.00
# QT_MAT_NACESTRANG               0.00
# QT_CONC_NACBRAS                 0.00
# QT_CONC_NACESTRANG              0.00
# QT_ALUNO_DEFICIENTE             0.00
# QT_ING_DEFICIENTE               0.00
# QT_MAT_DEFICIENTE               0.00
# QT_CONC_DEFICIENTE              0.00
# QT_ING_FINANC                   0.00
# QT_ING_FINANC_REEMB             0.00
# QT_ING_FIES                     0.00
# QT_ING_RPFIES                   0.00
# QT_ING_FINANC_REEMB_OUTROS      0.00
# QT_ING_FINANC_NREEMB            0.00
# QT_ING_PROUNII                  0.00
# QT_ING_PROUNIP                  0.00
# QT_ING_NRPFIES                  0.00
# QT_ING_FINANC_NREEMB_OUTROS     0.00
# QT_MAT_FINANC                   0.00
# QT_MAT_FINANC_REEMB             0.00
# QT_MAT_FIES                     0.00
# QT_MAT_RPFIES                   0.00
# QT_MAT_FINANC_REEMB_OUTROS      0.00
# QT_MAT_FINANC_NREEMB            0.00
# QT_MAT_PROUNII                  0.00
# QT_MAT_PROUNIP                  0.00
# QT_MAT_NRPFIES                  0.00
# QT_MAT_FINANC_NREEMB_OUTROS     0.00
# QT_CONC_FINANC                  0.00
# QT_CONC_FINANC_REEMB            0.00
# QT_CONC_FIES                    0.00
# QT_CONC_RPFIES                  0.00
# QT_CONC_FINANC_REEMB_OUTROS     0.00
# QT_CONC_FINANC_NREEMB           0.00
# QT_CONC_PROUNII                 0.00
# QT_CONC_PROUNIP                 0.00
# QT_CONC_NRPFIES                 0.00
# QT_CONC_FINANC_NREEMB_OUTROS    0.00
# QT_ING_RESERVA_VAGA             0.00
# QT_ING_RVREDEPUBLICA            0.00
# QT_ING_RVPDEF                   0.00
# QT_ING_RVSOCIAL_RF              0.00
# QT_ING_RVOUTROS                 0.00
# QT_MAT_RESERVA_VAGA             0.00
# QT_MAT_RVREDEPUBLICA            0.00
# QT_MAT_RVPDEF                   0.00
# QT_MAT_RVSOCIAL_RF              0.00
# QT_MAT_RVSOCIAL_RF.1            0.00
# QT_CONC_RESERVA_VAGA            0.00
# QT_CONC_RVREDEPUBLICA           0.00
# QT_CONC_RVSOCIAL_RF             0.00
# QT_CONC_RVOUTROS                0.00
# QT_SIT_TRANCADA                 0.00
# QT_SIT_DESVINCULADO             0.00
# QT_SIT_TRANSFERIDO              0.00
# QT_SIT_FALECIDO                 0.00
# QT_ING_PROCESCPUBLICA           0.00
# QT_ING_PROCESCPRIVADA           0.00
# QT_ING_PROCNAOINFORMADA         0.00
# QT_MAT_PROCESCPUBLICA           0.00
# QT_MAT_PROCESCPRIVADA           0.00
# QT_MAT_PROCNAOINFORMADA         0.00
# QT_CONC_PROCESCPUBLICA          0.00
# QT_CONC_PROCESCPRIVADA          0.00
# QT_CONC_PROCNAOINFORMADA        0.00
# QT_PARFOR                       0.00
# QT_ING_PARFOR                   0.00
# QT_MAT_PARFOR                   0.00
# QT_CONC_PARFOR                  0.00
# QT_APOIO_SOCIAL                 0.00
# QT_ING_APOIO_SOCIAL             0.00
# QT_MAT_APOIO_SOCIAL             0.00
# QT_CONC_APOIO_SOCIAL            0.00
# QT_ATIV_EXTRACURRICULAR         0.00
# QT_ING_ATIV_EXTRACURRICULAR     0.00
# QT_MAT_ATIV_EXTRACURRICULAR     0.00
# QT_CONC_ATIV_EXTRACURRICULAR    0.00
# QT_MOB_ACADEMICA                0.00
# QT_ING_MOB_ACADEMICA            0.00
# QT_MAT_MOB_ACADEMICA            0.00
# QT_CONC_MOB_ACADEMICA           0.00
# dtype: float64

# %% [markdown]
# Aplicação da função .map() para otimização **'NO_REGIAO'**

# %%
# 1. Verificando as dimensões do df lookup (Capastro_ies - fonte de mapeamento)
ies_21.shape
# Out:
# (2574, 9)

# %%
# 1.2 Verificando se existe dados duplicados na variável chave do df lookup
ies_21['CO_IES'].duplicated().sum()
# Out:
# 0

# %%
# 2. Criação da série de mapeamento (dicionário de lookup) index= CO_IES (chave) Values = 'NO_REGIAO'
map_cat1 = ies_21.set_index('CO_IES')['NO_REGIAO_IES']
# O método .drop_duplicates() é essencial para garantir que a chave (CO_IES) seja única, evitando que o .map() falhe ou retorne valores incorretos.
#map_cat1 = map_cat1.drop_duplicates() # no caso atual, não é necessário pois a os registro do df ies_10 são 1 para 1.

# %%
map_cat1.head()
# Out:
# CO_IES
# 1    Centro-Oeste
# 2    Centro-Oeste
# 3        Nordeste
# 4           Norte
# 5        Nordeste
# Name: NO_REGIAO_IES, dtype: object

# %%
# Gerando uma nova serie com os valores do mapeamento
cat_map = df_2021['CO_IES'].map(map_cat1)

# %%
df_2021['NO_REGIAO'] = df_2021['NO_REGIAO'].fillna(cat_map)

# %%
df_2021['NO_REGIAO'].isna().sum()
# Out:
# 0

# %% [markdown]
# Aplicando a função na variável **'CO_REGIAO'**

# %%
# 1. Criação da série de mapeamentos (lookup)
map_cat2 = ies_21.set_index('CO_IES')['CO_REGIAO_IES']

# %%
# 2. Gerando série com os valores do mapeamento
cat_map2 = df_2021['CO_IES'].map(map_cat2)

# %%
# 3. Preechimento de valores com .fillna()
df_2021['CO_REGIAO'] = df_2021['CO_REGIAO'].fillna(cat_map2)

# %%
# 4. Validando a aplicação
df_2021['CO_REGIAO'].isna().sum()
# Out:
# 0

# %% [markdown]
# Aplicando a função na variável **'NO_UF'**

# %%
# 1. Criação da série de mapeamento (lookup)
map_cat3 = ies_21.set_index('CO_IES')['NO_UF_IES']

# %%
# 2. Gerando série com os valores do mapeamento
cat_map3 = df_2021['CO_IES'].map(map_cat3)

# %%
# 3. Preenchimento de valores com .fillna()
df_2021['NO_UF'] = df_2021['NO_UF'].fillna(cat_map3)

# %%
# 4. Validação da aplicação
df_2021['NO_UF'].isna().sum()
# Out:
# 0

# %% [markdown]
# Aplicando a função na variável **'SG_UF'**

# %%
# 1. Criação da série de mapeamento (lookup)
map_cat4 = ies_21.set_index('CO_IES')['SG_UF_IES']

# %%
# 2. Gerando série com os valores do mapeamento
cat_map4 = df_2021['CO_IES'].map(map_cat4)

# %%
# 3. Preenchimento de valores com .fillna()
df_2021['SG_UF'] = df_2021['SG_UF'].fillna(cat_map4)

# %%
# 4. Validação da aplicação
df_2021['SG_UF'].isna().sum()
# Out:
# 0

# %% [markdown]
# Aplicando a função na variável **'CO_UF'**

# %%
df_2021.CO_UF.isna().sum()
# Out:
# 7948

# %%
# 1. Criação de série de mapeamento (lookup)
map_cat5 = ies_21.set_index('CO_IES')['CO_UF_IES']

# %%
# 2. Gerando série com os valores do mapemento
cat_map5 = df_2021['CO_IES'].map(map_cat5)

# %%
# 3. Preechimento de valores com .fillna()
df_2021['CO_UF'] = df_2021['CO_UF'].fillna(cat_map5)

# %%
# 4. Validação da aplicação
df_2021.CO_UF.isna().sum()
# Out:
# 0

# %% [markdown]
# Aplicando a função na variável **'NO_MUNICIPIO'**

# %%
df_2021.NO_MUNICIPIO.isna().sum()
# Out:
# 7948

# %%
# 1. Criação de série de mapeamento (lookup)
map_cat6 = ies_21.set_index('CO_IES')['NO_MUNICIPIO_IES']

# %%
# 2. Gerando série com os valores do mapeamento
cat_map6 = df_2021['CO_IES'].map(map_cat6)

# %%
# 3. Preenchimento de valores com fillna()
df_2021['NO_MUNICIPIO'] = df_2021['NO_MUNICIPIO'].fillna(cat_map6)

# %%
# 4. Validação
df_2021['NO_MUNICIPIO'].isna().sum()
# Out:
# 0

# %% [markdown]
# Aplicando a função na variável **'CO_MUNICIPIO'**

# %%
df_2021.CO_MUNICIPIO.isna().sum()
# Out:
# 7948

# %%
# 1. Criação de série de mapeamento (lookup)
map_cat7 = ies_21.set_index('CO_IES')['CO_MUNICIPIO_IES']

# %%
# 2. Gerando série com os valores do mapeamento
cat_map7 = df_2021['CO_IES'].map(map_cat7)

# %%
# 3. Preenchimento de valores com fillna()
df_2021['CO_MUNICIPIO'] = df_2021['CO_MUNICIPIO'].fillna(cat_map7)

# %%
# 4. Validação
df_2021['CO_MUNICIPIO'].isna().sum()
# Out:
# 0

# %% [markdown]
# Aplicando a função na variável **'CO_MUNICIPIO'**

# %%
df_2021.IN_CAPITAL.isna().sum()
# Out:
# 7948

# %%
# 1. Criação de série de mapeamento (lookup)
map_cat8 = ies_21.set_index('CO_IES')['IN_CAPITAL_IES']

# %%
# 2. Gerando série com os valores do mapeamento
cat_map8 = df_2021['CO_IES'].map(map_cat8)

# %%
# 3. Preenchimento de valores com fillna()
df_2021['IN_CAPITAL'] = df_2021['IN_CAPITAL'].fillna(cat_map8)

# %%
# 4. Validação
df_2021['IN_CAPITAL'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Aplicação de imputação condicional para para preencher os valores ausentes da variável 'TP_REDE'

# %%
# 1. Definindo os valores da variável que serão usadas para validação
#ies_publicas = [1, 2, 3] # TP_CATEGORIA_ADMINISTRATIVA (PÚBLICA)
# 2. Definindo a condição de nulidade da variável TP_REDE
#cond_na = df_2013['TP_REDE'].isna()
# 3. Definindo a condição da coluna secundária
#cond_sec = df_2013['TP_CATEGORIA_ADMINISTRATIVA'].isin(ies_publicas)
# 4. Combinando as duas condições (NA e [1, 2, 3])
#conditions = (cond_na & cond_sec)
# 5. Aplicando a alteração (imputação condicional)
#valor = 1
#df_2013.loc[conditions, 'TP_REDE'] = valor

# %%
# print(f" Aplicado em {conditions.sum()} registros")

# %%
# 1. Definindo  os valores da variável que será usada para validação
#ies_privadas = [4, 5, 6, 7, 8, 9]
# 2. Condição de nulidade
#cond_na2 = df_2013['TP_REDE'].isna()
# 3. Coluna segundária
#cond_sec2 = df_2013['TP_CATEGORIA_ADMINISTRATIVA'].isin(ies_privadas)
# 4. Combinando as duas condições
#condictions2 = (cond_na2 & cond_sec2)
# 5. Aplicar a Alteração
#valor2 = 2
#df_2013.loc[condictions2, 'TP_REDE'] = valor2

# %%
#print(f"Aplicado em {condictions2.sum()} registros")

# %%
# Restam valores ausentes?
#df_2013['TP_REDE'].isna().sum()

# %%
# Existem outras variáveis com valores ausentes?
(df_2021.isna().mean()*100).round(2)
# Out:
# NU_ANO_CENSO                    0.0
# CO_IES                          0.0
# NO_CURSO                        0.0
# CO_CURSO                        0.0
# TP_GRAU_ACADEMICO               0.0
# IN_GRATUITO                     0.0
# TP_MODALIDADE_ENSINO            0.0
# TP_NIVEL_ACADEMICO              0.0
# NO_CINE_AREA_GERAL              0.0
# CO_CINE_AREA_GERAL              0.0
# CO_CINE_AREA_ESPECIFICA         0.0
# NO_CINE_AREA_ESPECIFICA         0.0
# CO_CINE_AREA_DETALHADA          0.0
# NO_CINE_AREA_DETALHADA          0.0
# NO_REGIAO                       0.0
# CO_REGIAO                       0.0
# NO_UF                           0.0
# SG_UF                           0.0
# CO_UF                           0.0
# NO_MUNICIPIO                    0.0
# CO_MUNICIPIO                    0.0
# IN_CAPITAL                      0.0
# TP_DIMENSAO                     0.0
# TP_ORGANIZACAO_ACADEMICA        0.0
# TP_REDE                         0.0
# TP_CATEGORIA_ADMINISTRATIVA     0.0
# QT_CURSO                        0.0
# QT_VG_TOTAL                     0.0
# QT_VG_TOTAL_DIURNO              0.0
# QT_VG_TOTAL_NOTURNO             0.0
# QT_VG_TOTAL_EAD                 0.0
# QT_VG_NOVA                      0.0
# QT_VG_PROC_SELETIVO             0.0
# QT_VG_REMANESC                  0.0
# QT_VG_PROG_ESPECIAL             0.0
# QT_INSCRITO_TOTAL               0.0
# QT_INSCRITO_TOTAL_DIURNO        0.0
# QT_INSCRITO_TOTAL_NOTURNO       0.0
# QT_INSCRITO_TOTAL_EAD           0.0
# QT_INSC_VG_NOVA                 0.0
# QT_INSC_PROC_SELETIVO           0.0
# QT_INSC_VG_REMANESC             0.0
# QT_INSC_VG_PROG_ESPECIAL        0.0
# QT_ING                          0.0
# QT_ING_FEM                      0.0
# QT_ING_MASC                     0.0
# QT_ING_DIURNO                   0.0
# QT_ING_NOTURNO                  0.0
# QT_ING_VG_NOVA                  0.0
# QT_ING_VESTIBULAR               0.0
# QT_ING_ENEM                     0.0
# QT_ING_AVALIACAO_SERIADA        0.0
# QT_ING_SELECAO_SIMPLIFICA       0.0
# QT_ING_EGR                      0.0
# QT_ING_OUTRO_TIPO_SELECAO       0.0
# QT_ING_PROC_SELETIVO            0.0
# QT_ING_VG_REMANESC              0.0
# QT_ING_VG_PROG_ESPECIAL         0.0
# QT_ING_OUTRA_FORMA              0.0
# QT_ING_0_17                     0.0
# QT_ING_18_24                    0.0
# QT_ING_25_29                    0.0
# QT_ING_30_34                    0.0
# QT_ING_35_39                    0.0
# QT_ING_40_49                    0.0
# QT_ING_50_59                    0.0
# QT_ING_60_MAIS                  0.0
# QT_ING_BRANCA                   0.0
# QT_ING_PRETA                    0.0
# QT_ING_PARDA                    0.0
# QT_ING_AMARELA                  0.0
# QT_ING_INDIGENA                 0.0
# QT_ING_CORND                    0.0
# QT_MAT                          0.0
# QT_MAT_FEM                      0.0
# QT_MAT_MASC                     0.0
# QT_MAT_DIURNO                   0.0
# QT_MAT_NOTURNO                  0.0
# QT_MAT_0_17                     0.0
# QT_MAT_18_24                    0.0
# QT_MAT_25_29                    0.0
# QT_MAT_30_34                    0.0
# QT_MAT_35_39                    0.0
# QT_MAT_40_49                    0.0
# QT_MAT_50_59                    0.0
# QT_MAT_60_MAIS                  0.0
# QT_MAT_BRANCA                   0.0
# QT_MAT_PRETA                    0.0
# QT_MAT_PARDA                    0.0
# QT_MAT_AMARELA                  0.0
# QT_MAT_INDIGENA                 0.0
# QT_MAT_CORND                    0.0
# QT_CONC                         0.0
# QT_CONC_FEM                     0.0
# QT_CONC_MASC                    0.0
# QT_CONC_DIURNO                  0.0
# QT_CONC_NOTURNO                 0.0
# QT_CONC_0_17                    0.0
# QT_CONC_18_24                   0.0
# QT_CONC_25_29                   0.0
# QT_CONC_30_34                   0.0
# QT_CONC_35_39                   0.0
# QT_CONC_40_49                   0.0
# QT_CONC_50_59                   0.0
# QT_CONC_60_MAIS                 0.0
# QT_CONC_BRANCA                  0.0
# QT_CONC_PRETA                   0.0
# QT_CONC_PRETA.1                 0.0
# QT_CONC_AMARELA                 0.0
# QT_CONC_INDIGENA                0.0
# QT_CONC_CORND                   0.0
# QT_ING_NACBRAS                  0.0
# QT_ING_NACESTRANG               0.0
# QT_MAT_NACBRAS                  0.0
# QT_MAT_NACESTRANG               0.0
# QT_CONC_NACBRAS                 0.0
# QT_CONC_NACESTRANG              0.0
# QT_ALUNO_DEFICIENTE             0.0
# QT_ING_DEFICIENTE               0.0
# QT_MAT_DEFICIENTE               0.0
# QT_CONC_DEFICIENTE              0.0
# QT_ING_FINANC                   0.0
# QT_ING_FINANC_REEMB             0.0
# QT_ING_FIES                     0.0
# QT_ING_RPFIES                   0.0
# QT_ING_FINANC_REEMB_OUTROS      0.0
# QT_ING_FINANC_NREEMB            0.0
# QT_ING_PROUNII                  0.0
# QT_ING_PROUNIP                  0.0
# QT_ING_NRPFIES                  0.0
# QT_ING_FINANC_NREEMB_OUTROS     0.0
# QT_MAT_FINANC                   0.0
# QT_MAT_FINANC_REEMB             0.0
# QT_MAT_FIES                     0.0
# QT_MAT_RPFIES                   0.0
# QT_MAT_FINANC_REEMB_OUTROS      0.0
# QT_MAT_FINANC_NREEMB            0.0
# QT_MAT_PROUNII                  0.0
# QT_MAT_PROUNIP                  0.0
# QT_MAT_NRPFIES                  0.0
# QT_MAT_FINANC_NREEMB_OUTROS     0.0
# QT_CONC_FINANC                  0.0
# QT_CONC_FINANC_REEMB            0.0
# QT_CONC_FIES                    0.0
# QT_CONC_RPFIES                  0.0
# QT_CONC_FINANC_REEMB_OUTROS     0.0
# QT_CONC_FINANC_NREEMB           0.0
# QT_CONC_PROUNII                 0.0
# QT_CONC_PROUNIP                 0.0
# QT_CONC_NRPFIES                 0.0
# QT_CONC_FINANC_NREEMB_OUTROS    0.0
# QT_ING_RESERVA_VAGA             0.0
# QT_ING_RVREDEPUBLICA            0.0
# QT_ING_RVPDEF                   0.0
# QT_ING_RVSOCIAL_RF              0.0
# QT_ING_RVOUTROS                 0.0
# QT_MAT_RESERVA_VAGA             0.0
# QT_MAT_RVREDEPUBLICA            0.0
# QT_MAT_RVPDEF                   0.0
# QT_MAT_RVSOCIAL_RF              0.0
# QT_MAT_RVSOCIAL_RF.1            0.0
# QT_CONC_RESERVA_VAGA            0.0
# QT_CONC_RVREDEPUBLICA           0.0
# QT_CONC_RVSOCIAL_RF             0.0
# QT_CONC_RVOUTROS                0.0
# QT_SIT_TRANCADA                 0.0
# QT_SIT_DESVINCULADO             0.0
# QT_SIT_TRANSFERIDO              0.0
# QT_SIT_FALECIDO                 0.0
# QT_ING_PROCESCPUBLICA           0.0
# QT_ING_PROCESCPRIVADA           0.0
# QT_ING_PROCNAOINFORMADA         0.0
# QT_MAT_PROCESCPUBLICA           0.0
# QT_MAT_PROCESCPRIVADA           0.0
# QT_MAT_PROCNAOINFORMADA         0.0
# QT_CONC_PROCESCPUBLICA          0.0
# QT_CONC_PROCESCPRIVADA          0.0
# QT_CONC_PROCNAOINFORMADA        0.0
# QT_PARFOR                       0.0
# QT_ING_PARFOR                   0.0
# QT_MAT_PARFOR                   0.0
# QT_CONC_PARFOR                  0.0
# QT_APOIO_SOCIAL                 0.0
# QT_ING_APOIO_SOCIAL             0.0
# QT_MAT_APOIO_SOCIAL             0.0
# QT_CONC_APOIO_SOCIAL            0.0
# QT_ATIV_EXTRACURRICULAR         0.0
# QT_ING_ATIV_EXTRACURRICULAR     0.0
# QT_MAT_ATIV_EXTRACURRICULAR     0.0
# QT_CONC_ATIV_EXTRACURRICULAR    0.0
# QT_MOB_ACADEMICA                0.0
# QT_ING_MOB_ACADEMICA            0.0
# QT_MAT_MOB_ACADEMICA            0.0
# QT_CONC_MOB_ACADEMICA           0.0
# dtype: float64

# %%
# Salvando em .csv
df_2021.to_csv('censo_2021.csv', sep=';', encoding=cod_23, index=False)

# %% [markdown]
# ### Fim
